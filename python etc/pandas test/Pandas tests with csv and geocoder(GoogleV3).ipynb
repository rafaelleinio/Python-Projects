# %% [raw]
# import os
# os.listdir()

# %%
import pandas

# %%
df1 = pandas.read_csv("supermarkets.csv")
df1.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
from geopy import geocoders

# %%
g = geocoders.GoogleV3(api_key="AIzaSyDZy6kWX8oN-pT96HqzgdSBNtJJSzc5cx8")

# %%
addres = "Rua Vera Lúcia Cardoso Silva Barros, 64"
location = g.geocode(addres,timeout=10)
location.point
# Out:
# Point(-23.2002422, -45.9379101, 0.0)

# %%
df1["Full Address"] = df1["Address"] +", "+df1["City"]
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                    Full Address
# 0          8     3666 21st St, San Francisco
# 1         15   735 Dolores St, San Francisco
# 2         25      332 Hill St, San Francisco
# 3         10     3995 23rd St, San Francisco
# 4         12  1056 Sanchez St, San Francisco
# 5         20  551 Alvarado St, San Francisco

# %%
df1["latitude"] = (df1["Full Address"].apply(g.geocode)).apply(lambda x: x.latitude)
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                    Full Address   latitude
# 0          8     3666 21st St, San Francisco  37.756633
# 1         15   735 Dolores St, San Francisco  37.757819
# 2         25      332 Hill St, San Francisco  37.708498
# 3         10     3995 23rd St, San Francisco  37.752935
# 4         12  1056 Sanchez St, San Francisco  37.752131
# 5         20  551 Alvarado St, San Francisco  37.753511

# %%
df1["longitude"] = (df1["Full Address"].apply(g.geocode)).apply(lambda x: x.longitude)
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                    Full Address   latitude   longitude
# 0          8     3666 21st St, San Francisco  37.756633 -122.429422
# 1         15   735 Dolores St, San Francisco  37.757819 -122.425337
# 2         25      332 Hill St, San Francisco  37.708498 -122.431361
# 3         10     3995 23rd St, San Francisco  37.752935 -122.431722
# 4         12  1056 Sanchez St, San Francisco  37.752131 -122.430028
# ...

# %%
df1.to_csv("supermarkets_with_coordinates.csv")
